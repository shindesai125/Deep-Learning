# %% [markdown]
# <a href="https://colab.research.google.com/github/shindesai125/Deep-Learning/blob/main/SimpleRNN_with_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Embedding, Flatten

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
vocab_size = 10000   # top words to keep
maxlen = 200         # max review length
embedding_dim = 32   # size of embedding vectors

# %%
# as the data is already preprocessed and tokenized will just apply padding only
X_train =pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test =pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
X_train.shape
# Out:
# (25000, 200)

# %%
X_test.shape
# Out:
# (25000, 200)

# %%
model=Sequential()
model.add(Embedding(10000, 2))
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))
# Force build
model.build(input_shape=(None, maxlen))
model.summary( )
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_20 (Embedding)        │ (None, 200, 2)         │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_17 (SimpleRNN)       │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,153 (82.63 KB)
#  Trainable params: 21,153 (82.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(1e-3), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train, y_train, epochs = 10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.5045 - loss: 0.6937 - val_accuracy: 0.4988 - val_loss: 0.6937
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5025 - loss: 0.6940 - val_accuracy: 0.4998 - val_loss: 0.6937
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5085 - loss: 0.6926 - val_accuracy: 0.5006 - val_loss: 0.6956
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5194 - loss: 0.6897 - val_accuracy: 0.5063 - val_loss: 0.6925
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5334 - loss: 0.6795 - val_accuracy: 0.5005 - val_loss: 0.6954
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5319 - loss: 0.6694 - val_accuracy: 0.5017 - val_loss: 0.6979
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.5370 - loss: 0.6714 - val_accuracy: 0.5021 - val_loss: 0.6942
# Epoch 8/10
# ...

# %%
# from tensorflow.keras.datasets import imdb
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
# from tensorflow.keras.optimizers import Adam

# # Parameters
# vocab_size = 10000
# maxlen = 500
# embedding_dim = 128

# # Load data
# (X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
# X_train = pad_sequences(X_train, maxlen=maxlen, padding='post')
# X_test = pad_sequences(X_test, maxlen=maxlen, padding='post')

# # Build model
# model = Sequential()
# model.add(Embedding(vocab_size, embedding_dim, input_length=maxlen))
# model.add(Bidirectional(LSTM(64, return_sequences=False)))
# model.add(Dropout(0.5))
# model.add(Dense(64, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))

# # Compile
# model.compile(optimizer=Adam(1e-3), loss='binary_crossentropy', metrics=['accuracy'])

# # Train
# history = model.fit(X_train, y_train,
#                     epochs=5,
#                     batch_size=64,
#                     validation_data=(X_test, y_test))
